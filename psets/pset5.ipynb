# %% [markdown]
# # 18.369 pset 5

# %%
# import a useful set of modules
from matplotlib import pyplot as plt
import numpy as np
import math
import meep as mp
from meep import mpb

# %% [markdown]
# ## Problem 2

# %% [markdown]
# ### Sample code: Square lattice of rods
# To start off with, here is some sample code computing the TM band diagram of a triangular lattice of dielectric rods in air.

# %%
ms = mpb.ModeSolver(
        resolution=32,
        num_bands=8,
    
        # a hexagonal/triangular lattice:
        geometry_lattice=mp.Lattice(size=mp.Vector3(1, 1),
                              basis1=mp.Vector3(math.sqrt(3)/2, 0.5),
                              basis2=mp.Vector3(math.sqrt(3)/2, -0.5)),
        
        # cylindrical rods with radius 0.2a and epsilon=12
        geometry=[mp.Cylinder(0.2, material=mp.Medium(epsilon=12))],
    
        # the corners of the irreducible Brillouin zone
        k_points = mp.interpolate(9, [
            mp.Vector3(),               # Gamma
            mp.Vector3(y=0.5),          # M
            mp.Vector3(-1./3, 1./3),    # K
            mp.Vector3(),               # Gamma
        ]))
ms.run_tm()
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 31 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.05, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.15000000000000002, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.25, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.35000000000000003, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.45, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.03333333333333333, 0.48333333333333334, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.1, 0.45, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.16666666666666666, 0.41666666666666663, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.23333333333333334, 0.3833333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3, 0.35, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.3, 0.3, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.2333333333333333, 0.2333333333333333, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.16666666666666666, 0.16666666666666666, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.09999999999999998, 0.09999999999999998, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<-0.033333333333333326, 0.033333333333333326, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.0190126895904541
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 17 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.560518, 0.560561, 0.593296, 0.837451, 0.837595, 0.994129, 1.09832
# elapsed time for k point: 0.05945301055908203
# solve_kpoint (0,0.05,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 2, 0, 0.05, 0, 0.057735, 0.0357664, 0.553069, 0.560246, 0.601338, 0.836627, 0.838048, 0.992678, 1.09557
# elapsed time for k point: 0.042291879653930664
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 3, 0, 0.1, 0, 0.11547, 0.0711319, 0.538981, 0.559429, 0.617095, 0.834123, 0.839462, 0.988272, 1.08637
# elapsed time for k point: 0.038825035095214844
# solve_kpoint (0,0.15,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 4, 0, 0.15, 0, 0.173205, 0.10567, 0.523769, 0.558165, 0.635043, 0.830167, 0.841685, 0.980613, 1.07075
# elapsed time for k point: 0.03417491912841797
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 5, 0, 0.2, 0, 0.23094, 0.138898, 0.508574, 0.556587, 0.65398, 0.825087, 0.84452, 0.968999, 1.05281
# elapsed time for k point: 0.041249990463256836
# solve_kpoint (0,0.25,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 6, 0, 0.25, 0, 0.288675, 0.170235, 0.493763, 0.554857, 0.673463, 0.819314, 0.847713, 0.952834, 1.03723
# elapsed time for k point: 0.04052090644836426
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 7, 0, 0.3, 0, 0.34641, 0.198939, 0.479631, 0.553145, 0.693119, 0.813353, 0.850964, 0.932869, 1.02598
# elapsed time for k point: 0.03787732124328613
# solve_kpoint (0,0.35,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:,
at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0983183794354299 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.27469022653002567) to band 2 (0.44533108150360934), 47.39883474826619%
# Gap from band 3 (0.5605608042945375) to band 4 (0.5932960877473548), 5.674062993182485%
# Gap from band 4 (0.7907195985811134) to band 5 (0.7908094251751328), 0.01135946197256679%
# Gap from band 5 (0.8374511216215035) to band 6 (0.8375948535158122), 0.017161546183463498%
# Gap from band 6 (0.8682459356709961) to band 7 (0.8691349966528144), 0.10234496825392676%
# total elapsed time for run: 1.0035231113433838
# done

# %% [markdown]
# ### Sample code: Hexagonal lattice of rods
# To start off with, here is some sample code computing the TM band diagram of a hexagonal lattice of dielectric rods in air.

# %%
ms = mpb.ModeSolver(
        resolution=32,
        num_bands=8,
    
        # a hexagonal/triangular lattice:
        geometry_lattice=mp.Lattice(size=mp.Vector3(1, 1),
                              basis1=mp.Vector3(math.sqrt(3)/2, 0.5),
                              basis2=mp.Vector3(math.sqrt(3)/2, -0.5)),
        
        # cylindrical rods with radius 0.2a and epsilon=12
        geometry=[mp.Cylinder(0.2, material=mp.Medium(epsilon=12))],
    
        # the corners of the irreducible Brillouin zone
        k_points = mp.interpolate(9, [
            mp.Vector3(),               # Gamma
            mp.Vector3(0, 0.5),         # M
            mp.Vector3(-1./3, 1./3),    # K
            mp.Vector3(),               # Gamma
        ]))
ms.run_tm()
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 31 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.05, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.15000000000000002, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.25, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.35000000000000003, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.45, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.03333333333333333, 0.48333333333333334, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.1, 0.45, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.16666666666666666, 0.41666666666666663, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.23333333333333334, 0.3833333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3, 0.35, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.3, 0.3, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.2333333333333333, 0.2333333333333333, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.16666666666666666, 0.16666666666666666, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.09999999999999998, 0.09999999999999998, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<-0.033333333333333326, 0.033333333333333326, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.018818140029907227
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 16 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0
,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 30, -0.0333333, 0.0333333, 0, 0.0666667, 0.0412739, 0.551109, 0.560131, 0.603505, 0.836309, 0.838244, 0.992195, 1.09457
# elapsed time for k point: 0.0379481315612793
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 8 iterations.
# tmfreqs:, 31, 0, 0, 0, 0, 0, 0.560518, 0.560561, 0.593296, 0.837451, 0.837595, 0.994129, 1.09832
# elapsed time for k point: 0.026999711990356445
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.27469022653002606 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.4453310815036092 at Vector3<0.0, 0.5, 0.0> to 0.5605181473770023 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.49023891514891227 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.5605608042945378 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5932960889682306 at Vector3<0.0, 0.0, 0.0> to 0.7907195985811131 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.7908094251751339 at Vector3<-0.3, 0.35, 0.0> to 0.8374511216215018 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.837594856331134 at Vector3<0.0, 0.0, 0.0> to 0.8682459356709956 at Vector3<-0.16666666666666666, 0.41666666666666663, 0.0>
# Band 7 range: 0.8691349966528144 at Vector3<-0.13333333333333333, 0.43333333333333335, 0.0> to 0.9941291186140653 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8992499101138312 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0983183794354299 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.27469022653002606) to band 2 (0.4453310815036092), 47.39883474826603%
# Gap from band 3 (0.5605608042945378) to band 4 (0.5932960889682306), 5.674063198795308%
# Gap from band 4 (0.7907195985811131) to band 5 (0.7908094251751339), 0.011359461972749302%
# Gap from band 5 (0.8374511216215018) to band 6 (0.837594856331134), 0.017161882303412403%
# Gap from band 6 (0.8682459356709956) to band 7 (0.8691349966528144), 0.10234496825397792%
# total elapsed time for run: 1.1679468154907227
# done

# %% [markdown]
# It's always a good idea to plot a few periods of the crystal's $\varepsilon(x)$ function to make sure that the structure is what we think it is.   The `MPBData` tool is essential here, both to replicate the data over several periods (`periods=3`) and to convert it from the non-orthogonal (rhombus) primitive cell to a rectangular/Cartesian domain for plotting (`rectify=True`).  We'll plot the dielectric function alongside our band diagram.

# %%
plt.figure(figsize=(10,5))

md = mpb.MPBData(rectify=True, periods=3)
eps = md.convert(ms.get_epsilon())
plt.subplot(1,2,2)
plt.imshow(eps, cmap="binary")
plt.title("$example: \epsilon$ for hexagonal lattice of rods")

plt.subplot(1,2,1)
plt.plot(ms.all_freqs, "b.-")
plt.ylabel("frequency ($c/a$)")
plt.xticks([0,10,20,30], ["$\Gamma$","M","K","$\Gamma$"])
plt.grid()
plt.title("example: TM band diagram")
# Out:
# epsilon: 1-12, mean 2.59614, harm. mean 1.17149, 17.2852% > 1, 14.5104% "fill"
# Text(0.5, 1.0, 'example: TM band diagram')

# %% [markdown]
# We can also compute and print the fractional gap size via the maximum of the first band and the minimum of the second band:

# %%
band1_max = np.max(ms.all_freqs[:,0])
band2_min = np.min(ms.all_freqs[:,1])
gap = 200 * (band2_min - band1_max) / (band1_max + band2_min)
print("TM band gap = %g%%" % gap)
# Out:
# TM band gap = 47.3988%

# %% [markdown]
# ## your task:
#
# Now, make a modified version of the above code so that the angle between the primitive lattice vectors is 75° instead of 60°.   (The lattice vectors will still have length $a=1$, the rod radius is still $r=0.2a$, and the dielectric constant is still $\varepsilon=12$.
#
# 1. You will need to work out what the new irreducible Brillouin zone is.  Note that MPB requires you to write the `k_points` in the basis of the primitive reciprocal-lattice vectors.   If you compute these points in Cartesian coordinates, you can use the `mpb.cartesian_to_reciprocal(k, lattice)` function to convert, where the `lattice` argument is the same as your `geometry_lattice` parameter of the `ModeSolver`.
#
# 2. Compute the TM band diagram at least at the corners of the I.B.Z. as well as some interpolated points along the edges.
#
# 3. Plot the band diagram *and* the ε structure (over several unit cells), similar to above.
#
# 4. Compute the gap size, and compare it to the gap for the hexagonal lattice above.

# %% [markdown]
# # Problem 3

# %% [markdown]
# ### Sample code: Square lattice of rods
#
# To start off with, here is some sample code computing the TM band diagram of a square lattice of dielectric rods in air.

# %%
ms_sq = mpb.ModeSolver(
        resolution=32,
        num_bands=8,
    
        # a square lattice, period a=1:
        geometry_lattice=mp.Lattice(size=mp.Vector3(1, 1)),
        
        # cylindrical rods with radius 0.2a and epsilon=12
        geometry=[mp.Cylinder(0.2, material=mp.Medium(epsilon=12))],
    
        # the corners of the irreducible Brillouin zone
        k_points = mp.interpolate(9, [
            mp.Vector3(),               # Gamma
            mp.Vector3(0.5, 0),         # X
            mp.Vector3(0.5, 0.5),       # M
            mp.Vector3(),               # Gamma
        ]))
ms_sq.run_tm()
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (1, 0, 0)
#      (0, 1, 0)
#      (0, 0, 1)
# Cell volume = 1
# Reciprocal lattice vectors (/ 2 pi):
#      (1, -0, 0)
#      (-0, 1, -0)
#      (0, -0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 31 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.05, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.15000000000000002, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.25, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.35000000000000003, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.45, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.5, 0.05, 0.0>
#   Vector3<0.5, 0.1, 0.0>
#   Vector3<0.5, 0.15000000000000002, 0.0>
#   Vector3<0.5, 0.2, 0.0>
#   Vector3<0.5, 0.25, 0.0>
#   Vector3<0.5, 0.30000000000000004, 0.0>
#   Vector3<0.5, 0.35000000000000003, 0.0>
#   Vector3<0.5, 0.4, 0.0>
#   Vector3<0.5, 0.45, 0.0>
#   Vector3<0.5, 0.5, 0.0>
#   Vector3<0.45, 0.45, 0.0>
#   Vector3<0.4, 0.4, 0.0>
#   Vector3<0.35, 0.35, 0.0>
#   Vector3<0.3, 0.3, 0.0>
#   Vector3<0.25, 0.25, 0.0>
#   Vector3<0.19999999999999996, 0.19999999999999996, 0.0>
#   Vector3<0.14999999999999997, 0.14999999999999997, 0.0>
#   Vector3<0.09999999999999998, 0.09999999999999998, 0.0>
#   Vector3<0.04999999999999999, 0.04999999999999999, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.026852846145629883
# solve_kpoint (0,0,0):
# tmfreqs:, k index, k1, k2, k3, kmag/2pi, tm band 1, tm band 2, tm band 3, tm band 4, tm band 5, tm band 6, tm band 7, tm band 8
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 18 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.546027, 0.552094, 0.552096, 0.812093, 0.854314, 0.951107, 1.08259
# elapsed time for k point: 0.0800771713256836
# solve_kpoint (0.05,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 26 iterations.
# tmfreqs:, 2, 0.05, 0, 0, 0.05, 0.0323423, 0.533845, 0.552229, 0.564232, 0.81228, 0.853965, 0.94875, 1.0672
# elapsed time for k point: 0.12818527221679688
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 3, 0.1, 0, 0, 0.1, 0.0643671, 0.518896, 0.552617, 0.579095, 0.812721, 0.852958, 0.941428, 1.04995
# elapsed time for k point: 0.04438018798828125
# solve_kpoint (0.15,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 4, 0.15, 0, 0, 0.15, 0.0957356, 0.50357, 0.553223, 0.594425, 0.813015, 0.851408, 0.929034, 1.03725
# elapsed time for k point: 0.0453948974609375
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 5, 0.2, 0, 0, 0.2, 0.126061, 0.48795, 0.553991, 0.610359, 0.812384, 0.849484, 0.912816, 1.02959
# elapsed time for k point: 0.041522979736328125
# solve_kpoint (0.25,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 6, 0.25, 0, 0, 0.25, 0.154869, 0.472195, 0.554847, 0.627071, 0.809465, 0.847388, 0.895562, 1.02595
# elapsed time for k point: 0.04670906066894531
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 7, 0.3, 0, 0, 0.3, 0.181523, 0.45665, 0.555709, 0.644685, 0.802314, 0.845326, 0.880698, 1.025
# elapsed time for k point: 0.045500993728637695
# solve_kpoint (0.35,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 8, 0.35, 0, 0, 0.35, 0.205116, 0.441977, 0.556492, 0.663232, 0.789555, 0.843495, 0.870689, 1.02561
# elapsed time for k point: 0.043543100357055664
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 9, 0.4, 0, 0, 0.4, 0.224302, 0.429317, 0.557116, 0.682524, 0.772176, 0.842059, 0.865404, 1.0269
# elapsed time for k point: 0.04487204551696777
# solve_kpoint (0.45,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 10, 0.45, 0, 0, 0.45, 0.237206, 0.420392, 0.557519, 0.701602, 0.753227, 0.841144, 0.863127, 1.02808
# elapsed time for k point: 0.04444599151611328
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 11, 0.5, 0, 0, 0.5, 0.241821, 0.417114, 0.557658, 0.713395, 0.741311, 0.84083, 0.862516, 1.02856
# elapsed time for k point: 0.042337894439697266
# solve_kpoint (0.5,0.05,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 12, 0.5, 0.05, 0, 0.502494, 0.242692, 0.418763, 0.555943, 0.712942, 0.743512, 0.841112, 0.86254, 1.02555
# elapsed time for k point: 0.032659053802490234
# solve_kpoint (0.5,0.1,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 13, 0.5, 0.1, 0, 0.509902, 0.245235, 0.4236, 0.551085, 0.711571, 0.749855, 0.841982, 0.862609, 1.01714
# elapsed time for k point: 0.03472423553466797
# solve_kpoint (0.5,0.15,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 14, 0.5, 0.15, 0, 0.522015, 0.249252, 0.431297, 0.543813, 0.709265, 0.759695, 0.843512, 0.862718, 1.00465
# elapsed time for k point: 0.03699922561645508
# solve_kpoint (0.5,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 15, 0.5, 0.2, 0, 0.538516, 0.25442, 0.441321, 0.535034, 0.706018, 0.772267, 0.845818, 0.862861, 0.989395
# elapsed time for k point: 0.032904863357543945
# solve_kpoint (0.5,0.25,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 16, 0.5, 0.25, 0, 0.559017, 0.260309, 0.452941, 0.525647, 0.701889, 0.786879, 0.849051, 0.86303, 0.972357
# elapsed time for k point: 0.034948110580444336
# solve_kpoint (0.5,0.3,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 17, 0.5, 0.3, 0, 0.583095, 0.266397, 0.465222, 0.516482, 0.697068, 0.802974, 0.853388, 0.863228, 0.954203
# elapsed time for k point: 0.031333208084106445
# solve_kpoint (0.5,0.35,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 18, 0.5, 0.35, 0, 0.610328, 0.272093, 0.477022, 0.508306, 0.691965, 0.82009, 0.858995, 0.863482, 0.935393
# elapsed time for k point: 0.035009145736694336
# solve_kpoint (0.5,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 19, 0.5, 0.4, 0, 0.640312, 0.276774, 0.48701, 0.501823, 0.687264, 0.837704, 0.86397, 0.865932, 0.916273
# elapsed time for k point: 0.03542804718017578
# solve_kpoint (0.5,0.45,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 20, 0.5, 0.45, 0, 0.672681, 0.279865, 0.493785, 0.497643, 0.683867, 0.853899, 0.866258, 0.873658, 0.897185
# elapsed time for k point: 0.03708815574645996
# solve_kpoint (0.5,0.5,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 21, 0.5, 0.5, 0, 0.707107, 0.280948, 0.496196, 0.496197, 0.682617, 0.859474, 0.878316, 0.878316, 0.879351
# elapsed time for k point: 0.03826308250427246
# solve_kpoint (0.45,0.45,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 22, 0.45, 0.45, 0, 0.636396, 0.278705, 0.492982, 0.497608, 0.684931, 0.852474, 0.853908, 0.885419, 0.891907
# elapsed time for k point: 0.04393482208251953
# solve_kpoint (0.4,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 23, 0.4, 0.4, 0, 0.565685, 0.27141, 0.485365, 0.501693, 0.689111, 0.830636, 0.844978, 0.893706, 0.898991
# elapsed time for k point: 0.03802084922790527
# solve_kpoint (0.35,0.35,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 24, 0.35, 0.35, 0, 0.494975, 0.257727, 0.47772, 0.508023, 0.688749, 0.818971, 0.836648, 0.89511, 0.915158
# elapsed time for k point: 0.03493189811706543
# solve_kpoint (0.3,0.3,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 25, 0.3, 0.3, 0, 0.424264, 0.236529, 0.473888, 0.515941, 0.679199, 0.819377, 0.829518, 0.897603, 0.933446
# elapsed time for k point: 0.03262615203857422
# solve_kpoint (0.25,0.25,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 26, 0.25, 0.25, 0, 0.353553, 0.207854, 0.475659, 0.524638, 0.661782, 0.823707, 0.827826, 0.902302, 0.953873
# elapsed time for k point: 0.029043912887573242
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 27, 0.2, 0.2, 0, 0.282843, 0.172884, 0.482973, 0.533242, 0.640233, 0.819202, 0.838111, 0.910409, 0.976551
# elapsed time for k point: 0.03452301025390625
# solve_kpoint (0.15,0.15,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 28, 0.15, 0.15, 0, 0.212132, 0.133236, 0.494904, 0.540917, 0.617121, 0.81592, 0.846202, 0.922158, 1.00156
# elapsed time for k point: 0.038073062896728516
# solve_kpoint (0.1,0.1,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 29, 0.1, 0.1, 0, 0.141421, 0.0904174, 0.510404, 0.546943, 0.593803, 0.81373, 0.851132, 0.935551, 1.02882
# elapsed time for k point: 0.03866076469421387
# solve_kpoint (0.05,0.05,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 30, 0.05, 0.05, 0, 0.0707107, 0.0456646, 0.52855, 0.550779, 0.571077, 0.812492, 0.853586, 0.946673, 1.05783
# elapsed time for k point: 0.038847923278808594
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 13 iterations.
# tmfreqs:, 31, 0, 0, 0, 0, 0, 0.546027, 0.552094, 0.552096, 0.812093, 0.854314, 0.951107, 1.08259
# elapsed time for k point: 0.03776717185974121
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.28094795437968095 at Vector3<0.5, 0.5, 0.0>
# Band 2 range: 0.41711424967479915 at Vector3<0.5, 0.0, 0.0> to 0.5460267878039972 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.49619745312223523 at Vector3<0.5, 0.5, 0.0> to 0.5576576367260595 at Vector3<0.5, 0.0, 0.0>
# Band 4 range: 0.5520955872104775 at Vector3<0.0, 0.0, 0.0> to 0.7133951522965278 at Vector3<0.5, 0.0, 0.0>
# Band 5 range: 0.7413109665222849 at Vector3<0.5, 0.0, 0.0> to 0.8594741073451458 at Vector3<0.5, 0.5, 0.0>
# Band 6 range: 0.827826118171096 at Vector3<0.25, 0.25, 0.0> to 0.8783155715939374 at Vector3<0.5, 0.5, 0.0>
# Band 7 range: 0.8625159074396672 at Vector3<0.5, 0.0, 0.0> to 0.951107460154484 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8793510958348832 at Vector3<0.5, 0.5, 0.0> to 1.0825933106202508 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.28094795437968095) to band 2 (0.41711424967479915), 39.01265374467721%
# Gap from band 4 (0.7133951522965278) to band 5 (0.7413109665222849), 3.8380005232155137%
# total elapsed time for run: 1.359713077545166
# done

# %% [markdown]
# Plotting the result, similar to above, and computing the gap:

# %%
plt.figure(figsize=(10,5))

md = mpb.MPBData(rectify=True, periods=3)
eps = md.convert(ms_sq.get_epsilon())
plt.subplot(1,2,2)
plt.imshow(eps, cmap="binary")
plt.title("$example: \epsilon$ for square lattice of rods")

plt.subplot(1,2,1)
plt.plot(ms_sq.all_freqs, "b.-")
plt.ylabel("frequency ($c/a$)")
plt.xticks([0,10,20,30], ["$\Gamma$","X","M","$\Gamma$"])
plt.grid()
plt.title("example: TM square-lattice bands")

band1_max = np.max(ms_sq.all_freqs[:,0])
band2_min = np.min(ms_sq.all_freqs[:,1])
gap = 200 * (band2_min - band1_max) / (band1_max + band2_min)
print("TM band gap = %g%%" % gap)
# Out:
# epsilon: 1-12, mean 2.38229, harm. mean 1.1448, 14.5508% > 1, 12.5663% "fill"
# TM band gap = 39.0127%

# %% [markdown]
# ### part (a): Transmission through $N_x$ rods
#
# The following function computes the transmitted power $P(\omega)$ through a finite (in $x$) crystal consisting of $N_x$ rods, with air on either side, returning an array of frequencies, an array of powers, and the simulation object:

# %%
def transmitted_P(Nx=5, pad=4, dpml=1, fmin=0.2, fmax=0.8, nfreq=300):
    fcen = (fmin+fmax)*0.5
    df = fmax - fmin
    sx = Nx + 2*(pad+dpml)
    
    sim = mp.Simulation(cell_size=mp.Vector3(sx, 1),
                        
                        # make Nx duplicates of a rod:
                        geometry = mp.geometric_object_duplicates(mp.Vector3(1,0), 0, Nx-1, 
                                                                  mp.Cylinder(0.2, center=mp.Vector3(-0.5*sx+dpml+pad+0.5,0), material=mp.Medium(epsilon=12))),
 
                        
                        # absorbing boundaries in y direction, periodic in x
                        boundary_layers = [mp.PML(dpml, direction=mp.X)],
                        k_point = mp.Vector3(0,0), # ky=0 for normal incidence
                        
                        # source is a pulsed line source adjacent to PML
                        sources=[mp.Source(mp.GaussianSource(fcen, fwidth=df), mp.Ez,
                                           center=(-sx*0.5 + dpml,0), size=(0,1))],
                        
                        # to speed things up, exploit the y=0 mirror plane:
                        symmetries = [mp.Mirror(mp.Y, phase=1)],
                        resolution=20)
    
    # flux (power) monitor on transmitted side
    fluxregion = mp.FluxRegion(center=mp.Vector3(0.5*sx-dpml),
                               size=mp.Vector3(0,1))
    trans = sim.add_flux(fcen, df, nfreq, fluxregion)
    
    # run simulation until fields on transmitted side have decayed away
    sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(0.5*sx-dpml), 1e-3))
    return sim, np.array(mp.get_flux_freqs(trans)), np.array(mp.get_fluxes(trans))

# %% [markdown]
# Let's run it for $N_x = 5$ layers of the crystal:

# %%
sim,freqs,P5 = transmitted_P(Nx=5)
# Out:
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000792027 s
# Working in 2D dimensions.
# Computational cell is 15 x 1 x 0 with resolution 20
#      cylinder, center = (2,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      cylinder, center = (1,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      cylinder, center = (-1,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      cylinder, center = (-2,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (12,12,12)
# time for set_epsilon = 0.0250719 s
# -----------
# field decay(t = 50.025000000000006): 0.12373041360550532 / 0.12373041360550532 = 1.0
# field decay(t = 100.05000000000001): 0.0010195633208608414 / 0.12373041360550532 = 0.008240199730613981
# field decay(t = 150.07500000000002): 3.662547440559447e-05 / 0.12373041360550532 = 0.0002960102802401433
# run 0 finished at t = 150.07500000000002 (6003 timesteps)

# %% [markdown]
# As usual, it is always a good idea to visualize the simulation, to make sure you are running what you intend.  The Meep simulation object `sim` has a method `sim.plot2D()` that shows both the dielectric function ε (black circles), the PML regions (green striped boxes), the source location (red line) and the flux-monitor location (green line):

# %%
sim.plot2D()

# %% [markdown]
# We can also plot power (Poynting flux) measured through the transmission plane vs. frequency, but this is **not yet normalized**.  That is, we are plotting *absolute* power (in arbitrary units), whereas what we eventually want is to plot the *fraction of the incident power* that is transmitted.

# %%
plt.plot(freqs, P5)
plt.xlabel("frequency ($c/a$)")
plt.ylabel("transmitted power (arb. units)")
plt.title("unnormalized transmitted power")

# %% [markdown]
# Basically, it is the incident Gaussian pulse spectrum multiplied by the "wiggly" transmission spectrum.
#
# It is also nice to visualize the simulation in the form of an animation of the $E_z$ field, which is accomplished using the `Animate2D` object provided by Meep:

# %%
sim.reset_meep()
animate = mp.Animate2D(sim, fields=mp.Ez)
sim.run(mp.at_every(0.2,animate),until=50)
animate.to_jshtml(10)
# Out:
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000663996 s
# Working in 2D dimensions.
# Computational cell is 15 x 1 x 0 with resolution 20
#      cylinder, center = (2,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      cylinder, center = (1,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      cylinder, center = (-1,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      cylinder, center = (-2,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (12,12,12)
# time for set_epsilon = 0.0219939 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=50.0)
# Meep progress: 23.8/50.0 = 47.6% done in 4.0s, 4.4s to go
# on time step 952 (time=23.8), 0.00420758 s/step
# Meep progress: 48.6/50.0 = 97.2% done in 8.0s, 0.2s to go
# on time step 1944 (time=48.6), 0.00403389 s/step
# run 3 finished at t = 50.0 (2000 timesteps)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgbc2be16044604934a7e408bf4b9b47dc">
#   <div class="anim-controls">
#     <input id="_anim_sliderbc2be16044604934a7e408bf4b9b47dc" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animbc2be16044604934a7e408bf4b9b47dc.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animbc2be16044604934a7e408bf4b9b47dc.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animbc2be16044604934a7e408bf4b9b47dc.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animbc2be16044604934a7e408bf4b9b47dc.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animbc2be16044604934a7e408bf4b9b47dc.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animbc2be16044604934a7e408bf4b9b47dc.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animbc2be16044604934a7e408bf4b9b47dc.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animbc2be16044604934a7e408bf4b9b47dc.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animbc2be16044604934a7e408bf4b9b47dc.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animbc2be16044604934a7e408bf4b9b47dc.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectbc2be16044604934a7e408bf4b9b47dc" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_bc2be16044604934a7e408bf4b9b47dc"
#              >
#       <label for="_anim_radio1_bc2be16044604934a7e408bf4b9b47dc">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_bc2be16044604934a7e408bf4b9b47dc"
#              checked>
#       <label for="_anim_radio2_bc2be16044604934a7e408bf4b9b47dc">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_bc2be16044604934a7e408bf4b9b47dc"
#              >
#       <label for="_anim_radio3_bc2be16044604934a7e408bf4b9b47dc">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgbc2be16044604934a7e408bf4b9b47dc";
#     var slider_id = "_anim_sliderbc2be16044604934a7e408bf4b9b47dc";
#     var loop_select_id = "_anim_loop_selectbc2be16044604934a7e408bf4b9b47dc";
#     var frames = new Array(250);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAWzklEQVR4nO3de3CU9b3H8c8mm4QkGkhCQhI2kMRw\
# iUFEiQXbznTU4gVbeoqMtUMtFikzameoHWxz5kztjB2EY22rhR4ctK1Meyod2jOS0cKYUm0dRkS5\
# CAEBbRKaKyy5Qu7Zfc4fIZEQLpvrk2/yfs1wSbL7y5dseN7zPPvsE4/jOI4AADAmzO0BAAAYCAIG\
# ADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIG\
# ADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIG\
# ADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAAQBMImAAAJMIGADAJAIG\
# ADCJgAEATCJgAACTCBgAwCQCB

# %% [markdown]
# ### part (a)
#
# Compute the *normalized* transmission spectra for frequencies from $0.2c/a$ to $0.8c/a $as a function of $N_{x}$, for $N_{x}=1,2,3,5,6$, and plot them (together on a single plot). The transmission spectrum is the transmitted power spectrum (shown above) *normalized* by dividing by the transmitted power for $N_{x}=0$ (no holes).
#
# Try to explain the features of your transmission spectrum to the band diagram in the sample code.

# %% [markdown]
# ### part (b)
#
# Predict analytically at what frequency $\omega_{0}$ you should start to see additional diffracted orders in the reflected wave (i.e. reflected waves at angles in addition to the normal 0° reflection).
#
# Now, modify the simulation to use a TM continuous-wave (CW) source and output $E_{z}$ at the end and show that there is a qualitative change in the reflected field pattern if you put in a frequency just below $\omega_{0}$ versus a frequency just above $\omega_{0}$.
